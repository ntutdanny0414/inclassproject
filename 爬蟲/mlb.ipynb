# %%
import requests

# %%
url = "http://mlb.mlb.com/pubajax/wf/flow/stats.splayer?season=2018&sort_order=%27desc%27&sort_column=%27avg%27&stat_type=hitting&page_type=SortablePlayer&game_type=%27R%27&player_pool=QUALIFIER&season_type=ANY&sport_code=%27mlb%27&results=1000&recSP=1&recPP=50"

# %%
res = requests.get(url)

# %%
res.json()
res.json()['stats_sortable_player']["queryResults"]["row"]
# Out:
# [{'gidp': '4',
#   'sac': '0',
#   'np': '2055',
#   'name_display_first_last': 'Mookie Betts',
#   'pos': 'RF',
#   'rank': '1',
#   'tb': '272',
#   'team_brief': 'Red Sox',
#   'sport_id': '1',
#   'name_display_last_init': 'Betts, M',
#   'bb': '60',
#   'avg': '.340',
#   'slg': '.642',
#   'ops': '1.067',
#   'hbp': '6',
#   'team_abbrev': 'BOS',
#   'so': '69',
#   'league_id': '103',
#   'sf': '3',
#   'team': 'bos',
#   'league': 'AL',
#   'cs': '3',
#   'sb': '24',
#   'go_ao': '0.60',
#   'last_name': 'Betts',
#   'player_id': '605141',
#   'ibb': '8',
#   'player_qualifier': '493',
#   'team_id': '111',
#   'go': '82',
#   'hr': '27',
#   'minimum_qualifier': '397',
#   'gdp': '4',
#   'name_display_roster': 'Betts, Mookie',
#   'qualifies': 'Y',
#   'rbi': '64',
#   'name_first': 'Mookie',
#   'bats': 'R',
#   'xbh': '69',
#   'g': '108',
#   'd': '37',
#   'team_name': 'Boston Red Sox',
#   'sport': 'MLB',
#   'tpa': '493',
#   'name_display_last_first': 'Betts, Mookie',
#   'h': '144',
#   'obp': '.426',
#   't': '5',
#   'ao': '136',
#   'r': '102',
#   'ab': '424',
#   'name_last': 'Betts'},
#  {'gidp': '15',
#   'sac': '0',
#   'np': '2095',
#   'name_display_first_last': 'J.D. Martinez',
#   'pos': 'LF',
#   'rank': '2',
#   'tb': '304',
#   'team_brief': 'Red Sox',
#   'sport_id': '1',
#   'name_display_last_init': 'Martinez, J',
#   'bb': '53',
#   'avg': '.333',
#   'slg': '.657',
#   'ops': '1.059',
#   'hbp': '4',
#   'team_abbrev': 'BOS',
#   'so': '122',
#   'league_id': '103',
#   'sf': '4',
#   'team': 'bos',
#   'league': 'AL',
#   'cs': '1',
#   'sb': '5',
#   'go_ao': '1.51',
#   'last_name': 'Martinez',
#   'player_id': '502110',
#   'ibb': '6',
#   'player_qualifier': '524',
#   'team_id': '111',
#   'go': '124',
#   'hr': '38',
#   'minimum_qualifier': '397',
#   'gdp': '15',
#   'name_display_roster': 'Martinez, J.D.',
#   'qualifies': 'Y',
#   'rbi': '108',
#   'name_first': 'J.D.',
#   'bats': 'R',
#   'xbh': '73',
#   'g': '121',
#   'd': '34',
#   'team_name': 'Boston Red Sox',
#   'sport': 'MLB',
#   'tpa': '524',
#   'name_display_last_first': 'Martinez, J.D.',
#   'h': '154',
#   'obp': '.403',
#   't': '1',
#   'ao': '82',
#   'r': '94',
#   'ab': '463',
#   'name_last': 'Martinez'},
#  {'gidp': '12',
#   'sac': '3',
#   'np': '1643',
#   'name_display_first_last': 'Jose Altuve',
#   'pos': '2B',
#   'rank': '3',
#   'tb': '191',
#   'team_brief': 'Astros',
#   'sport_id': '1',
#   'name_display_last_init': 'Altuve, J',
#   'bb': '42',
#   'avg': '.328',
#   'slg': '.460',
#   'ops': '.852',
#   'hbp': '2',
#   'team_abbrev': 'HOU',
#   'so': '56',
#   'league_id': '103',
#   'sf': '1',
#   'team': 'hou',
#   'league': 'AL',
#   'cs': '2',
#   'sb': '15',
#   'go_ao': '1.15',
#   'last_name': 'Altuve',
#   'player_id': '514888',
#   'ibb': '4',
#   'player_qualifier': '463',
#   'team_id': '117',
#   'go': '128',
#   'hr': '9',
#   'minimum_qualifier': '394',
#   'gdp': '12',
#   'name_display_roster': 'Altuve, Jose',
#   'qualifies': 'Y',
#   'rbi': '47',
#   'name_first': 'Jose',
#   'bats': 'R',
#   'xbh': '35',
#   'g': '106',
#   'd': '24',
#   'team_name': 'Houston Astros',
#   'sport': 'MLB',
#   'tpa': '463',
#   'name_display_last_first': 'Altuve, Jose',
#   'h': '136',
#   'obp': '.391',
#   't': '2',
#   'ao': '111',
#   'r': '64',
#   'ab': '415',
#   'name_last': 'Altuve'},
#  {'gidp': '7',
#   'sac': '0',
#   'np': '2068',
#   'name_display_first_last': 'Freddie Freeman',
#   'pos': '1B',
#   'rank': '4',
#   'tb': '256',
#   'team_brief': 'Braves',
#   'sport_id': '1',
#   'name_display_last_init': 'Freeman, F',
#   'bb': '63',
#   'avg': '.319',
#   'slg': '.527',
#   'ops': '.927',
#   'hbp': '6',
#   'team_abbrev': 'ATL',
#   'so': '99',
#   'league_id': '104',
#   'sf': '4',
#   'team': 'atl',
#   'league': 'NL',
#   'cs': '3',
#   'sb': '8',
#   'go_ao': '1.03',
#   'last_name': 'Freeman',
#   'player_id': '518692',
#   'ibb': '9',
#   'player_qualifier': '559',
#   'team_id': '144',
#   'go': '123',
#   'hr': '20',
#   'minimum_qualifier': '391',
#   'gdp': '7',
#   'name_display_roster': 'Freeman, Freddie',
#   'qualifies': 'Y',
#   'rbi': '78',
#   'name_first': 'Freddie',
#   'bats': 'L',
#   'xbh': '58',
#   'g': '126',
#   'd': '35',
#   'team_name': 'Atlanta Braves',
#   'sport': 'MLB',
#   'tpa': '559',
#   'name_display_last_first': 'Freeman, Freddie',
#   'h': '155',
#   'obp': '.401',
#   't': '3',
#   'ao': '120',
#   'r': '79',
#   'ab': '486',
#   'name_last': 'Freeman'},
#  {'gidp': '16',
#   'sac': '3',
#   'np': '1834',
#   'name_display_first_last': 'Jean Segura',
#   'pos': 'SS',
#   'rank': '5',
#   'tb': '210',
#   'team_brief': 'Mariners',
#   'sport_id': '1',
#   'name_display_last_init': 'Segura, J',
#   'bb': '21',
#   'avg': '.315',
#   'slg': '.435',
#   'ops': '.778',
#   'hbp': '3',
#   'team_abbrev': 'SEA',
#   'so': '65',
#   'league_id': '103',
#   'sf': '6',
#   'team': 'sea',
#   'league': 'AL',
#   'cs': '10',
#   'sb': '17',
#   'go_ao': '1.35',
#   'last_name': 'Segura',
#   'player_id': '516416',
#   'ibb': '0',
#   'player_qualifier': '516',
#   'team_id': '136',
#   'go': '167',
#   'hr': '9',
#   'minimum_qualifier': '397',
#   'gdp': '16',
#   'name_display_roster': 'Segura, Jean',
#   'qualifies': 'Y',
#   'rbi': '57',
#   'name_first': 'Jean',
#   'bats': 'R',
#   'xbh': '38',
#   'g': '117',
#   'd': '27',
#   'team_name': 'Seattle Mariners',
#   'sport': 'MLB',
#   'tpa': '516',
#   'name_display_last_first': 'Segura, Jean',
#   'h': '152',
#   'obp': '.343',
#   't': '2',
#   'ao': '124',
#   'r': '78',
#   'ab': '483',
#   'name_last': 'Segura'},
#  {'gidp': '9',
#   'sac': '0',
#   'np': '1935',
#   'name_display_first_last': 'Christian Yelich',
#   'pos': 'LF',
#   'rank': '6',
#   'tb': '239',
#   'team_brief': 'Brewers',
#   'sport_id': '1',
#   'name_display_last_init': 'Yelich, C',
#   'bb': '42',
#   'avg': '.314',
#   'slg': '.532',
#   'ops': '.910',
#   'hbp': '5',
#   'team_abbrev': 'MIL',
#   'so': '113',
#   'league_id': '104',
#   'sf': '2',
#   'team': 'mil',
#   'league': 'NL',
#   'cs': '3',
#   'sb': '14',
#   'go_ao': '2.03',
#   'last_name': 'Yelich',
#   'player_id': '592885',
#   'ibb': '1',
#   'player_qualifier': '498',
#   'team_id': '158',
#   'go': '138',
#   'hr': '21',
#   'minimum_qualifier': '400',
#   'gdp': '9',
#   'name_display_roster': 'Yelich, Christian',
#   'qualifies': 'Y',
#   'rbi': '64',
#   'name_first': 'Christian',
#   'bats': 'L',
#   'xbh': '52',
#   'g': '113',
#   'd': '27',
#   'team_name': 'Milwaukee Brewers',
#   'sport': 'MLB',
#   'tpa': '498',
#   'name_display_last_first': 'Yelich, Christian',
#   'h': '141',
#   'obp': '.378',
#   't': '4',
#   'ao': '68',
#   'r': '87',
#   'ab': '449',
#   'name_last': 'Yelich'},
#  {'gidp': '16',
#   'sac': '0',
#   'np': '2191',
#   'name_display_first_last': 'Nick Markakis',
#   'pos': 'RF',
#   'rank': '7',
#   'tb': '237',
#   'team_brief': 'Braves',
#   'sport_id': '1',
#   'name_display_last_init': 'Markakis, N',
#   'bb': '53',
#   'avg': '.313',
#   'slg': '.482',
#   'ops': '.857',
#   'hbp': '1',
#   'team_abbrev': 'ATL',
#   'so': '62',
#   'league_id': '104',
#   'sf': '8',
#   'team': 'atl',
#   'league': 'NL',
#   'cs': '1',
#   'sb': '1',
#   'go_ao': '1.03',
#   'last_name': 'Markakis',
#   'player_id': '455976',
#   'ibb': '9',
#   'player_qualifier': '554',
#   'team_id': '144',
#   'go': '152',
#   'hr': '14',
#   'minimum_qualifier': '391',
#   'gdp': '16',
#   'name_display_roster': 'Markakis, Nick',
#   'qualifies': 'Y',
#   'rbi': '81',
#   'name_first': 'Nick',
#   'bats': 'L',
#   'xbh': '53',
#   'g': '126',
#   'd': '37',
#   'team_name': 'Atlanta Braves',
#   'sport': 'MLB',
#   'tpa': '554',
#   'name_display_last_first': 'Markakis, Nick',
#   'h': '154',
#   'obp': '.375',
#   't': '2',
#   'ao': '148',
#   'r': '69',
#   'ab': '492',
#   'name_last': 'Markakis'},
#  {'gidp': '12',
#   'sac': '3',
#   'np': '1964',
#   'name_display_first_last': 'Scooter Gennett',
#   'pos': '2B',
#   'rank': '8',
#   'tb': '230',
#   'team_brief': 'Reds',
#   'sport_id': '1',
#   'name_display_last_init': 'Gennett, S',
#   'bb': '33',
#   'avg': '.310',
#   'slg': '.493',
#   'ops': '.850',
#   'hbp': '4',
#   'team_abbrev': 'CIN',
#   'so': '101',
#   'league_id': '104',
#   'sf': '5',
#   'team': 'cin',
#   'league': 'NL',
#   'cs': '2',
#   'sb': '3',
#   'go_ao': '0.94',
#   'last_name': 'Gennett',
#   'player_id': '571697',
#   'ibb': '3',
#   'player_qualifier': '512',
#   'team_id': '113',
#   'go': '117',
#   'hr': '19',
#   'minimum_qualifier': '394',
#   'gdp': '12',
#   'name_display_roster': 'Gennett, Scooter',
#   'qualifies': 'Y',
#   'rbi': '75',
#   'name_first': 'Scooter',
#   'bats': 'L',
#   'xbh': '46',
#   'g': '123',
#   'd': '26',
#   'team_name': 'Cincinnati Reds',
#   'sport': 'MLB',
#   'tpa': '512',
#   'name_display_last_first': 'Gennett, Scooter',
#   'h': '145',
#   'obp': '.358',
#   't': '1',
#   'ao': '124',
#   'r': '74',
#   'ab': '467',
#   'name_last': 'Gennett'},
#  {'gidp': '5',
#   'sac': '0',
#   'np': '2029',
#   'name_display_first_last': 'Mike Trout',
#   'pos': 'CF',
#   'rank': '9',
#   'tb': '232',
#   'team_brief': 'Angels',
#   'sport_id': '1',
#   'name_display_last_init': 'Trout, M',
#   'bb': '99',
#   'avg': '.309',
#   'slg': '.624',
#   'ops': '1.083',
#   'hbp': '7',
#   'team_abbrev': 'LAA',
#   'so': '97',
#   'league_id': '103',
#   'sf': '3',
#   'team': 'ana',
#   'league': 'AL',
#   'cs': '2',
#   'sb': '21',
#   'go_ao': '0.71',
#   'last_name': 'Trout',
#   'player_id': '545361',
#   'ibb': '20',
#   'player_qualifier': '482',
#   'team_id': '108',
#   'go': '70',
#   'hr': '30',
#   'minimum_qualifier': '394',
#   'gdp': '5',
#   'name_display_roster': 'Trout, Mike',
#   'qualifies': 'Y',
#   'rbi': '60',
#   'name_first': 'Mike',
#   'bats': 'R',
#   'xbh': '54',
#   'g': '109',
#   'd': '21',
#   'team_name': 'Los Angeles Angels',
#   'sport': 'MLB',
#   'tpa': '482',
#   'name_display_last_first': 'Trout, Mike',
#   'h': '115',
#   'obp': '.459',
#   't': '3',
#   'ao': '98',
#   'r': '82',
#   'ab': '372',
#   'name_last': 'Trout'},
#  {'gidp': '12',
#   'sac': '0',
#   'np': '2031',
#   'name_display_first_last': 'Nolan Arenado',
#   'pos': '3B',
#   'rank': '10',
#   'tb': '258',
#   'team_brief': 'Rockies',
#   'sport_id': '1',
#   'name_display_last_init': 'Arenado, N',
#   'bb': '59',
#   'avg': '.309',
#   'slg': '.577',
#   'ops': '.968',
#   'hbp': '3',
#   'team_abbrev': 'COL',
#   'so': '91',
#   'league_id': '104',
#   'sf': '3',
#   'team': 'col',
#   'league': 'NL',
#   'cs': '2',
#   'sb': '2',
#   'go_ao': '0.88',
#   'last_name': 'Arenado',
#   'player_id': '571448',
#   'ibb': '6',
#   'player_qualifier': '512',
#   'team_id': '115',
#   'go': '109',
#   'hr': '30',
#   'minimum_qualifier': '388',
#   'gdp': '12',
#   'name_display_roster': 'Arenado, Nolan',
#   'qualifies': 'Y',
#   'rbi': '87',
#   'name_first': 'Nolan',
#   'bats': 'R',
#   'xbh': '58',
#   'g': '119',
#   'd': '26',
#   'team_name': 'Colorado Rockies',
#   'sport': 'MLB',
#   'tpa': '512',
#   'name_display_last_first': 'Arenado, Nolan',
#   'h': '138',
#   'obp': '.391',
#   't': '2',
#   'ao': '124',
#   'r': '80',
#   'ab': '447',
#   'name_last': 'Arenado'},
#  {'gidp': '13',
#   'sac': '0',
#   'np': '1812',
#   'name_display_first_last': 'Jose Martinez',
#   'pos': '1B',
#   'rank': '11',
#   'tb': '193',
#   'team_brief': 'Cardinals',
#   'sport_id': '1',
#   'name_display_last_init': 'Martinez, J',
#   'bb': '39',
#   'avg': '.308',
#   'slg': '.472',
#   'ops': '.841',
#   'hbp': '2',
#   'team_abbrev': 'STL',
#   'so': '71',
#   'league_id': '104',
#   'sf': '3',
#   'team': 'sln',
#   'league': 'NL',
#   'cs': '3',
#   'sb': '0',
#   'go_ao': '1.30',
#   'last_name': 'Martinez',
#   'player_id': '500874',
#   'ibb': '0',
#   'player_qualifier': '453',
#   'team_id': '138',
#   'go': '129',
#   'hr': '15',
#   'minimum_qualifier': '394',
#   'gdp': '13',
#   'name_display_roster': 'Martinez, Jose',
#   'qualifies': 'Y',
#   'rbi': '72',
#   'name_first': 'Jose',
#   'bats': 'R',
#   'xbh': '37',
#   'g': '119',
#   'd': '22',
#   'team_name': 'St. Louis Cardinals',
#   'sport': 'MLB',
#   'tpa': '453',
#   'name_display_last_first': 'Martinez, Jose',
#   'h': '126',
#   'obp': '.369',
#   't': '0',
#   'ao': '99',
#   'r': '45',
#   'ab': '409',
#   'name_last': 'Martinez'},
#  {'gidp': '6',
#   'sac': '0',
#   'np': '1922',
#   'name_display_first_last': 'Lorenzo Cain',
#   'pos': 'CF',
#   'rank': '12',
#   'tb': '177',
#   'team_brief': 'Brewers',
#   'sport_id': '1',
#   'name_display_last_init': 'Cain, L',
#   'bb': '58',
#   'avg': '.307',
#   'slg': '.424',
#   'ops': '.823',
#   'hbp': '6',
#   'team_abbrev': 'MIL',
#   'so': '75',
#   'league_id': '104',
#   'sf': '1',
#   'team': 'mil',
#   'league': 'NL',
#   'cs': '7',
#   'sb': '24',
#   'go_ao': '1.66',
#   'last_name': 'Cain',
#   'player_id': '456715',
#   'ibb': '0',
#   'player_qualifier': '482',
#   'team_id': '158',
#   'go': '138',
#   'hr': '9',
#   'minimum_qualifier': '400',
#   'gdp': '6',
#   'name_display_roster': 'Cain, Lorenzo',
#   'qualifies': 'Y',
#   'rbi': '32',
#   'name_first': 'Lorenzo',
#   'bats': 'R',
#   'xbh': '30',
#   'g': '110',
#   'd': '20',
#   'team_name': 'Milwaukee Brewers',
#   'sport': 'MLB',
#   'tpa': '482',
#   'name_display_last_first': 'Cain, Lorenzo',
#   'h': '128',
#   'obp': '.398',
#   't': '1',
#   'ao': '83',
#   'r': '65',
#   'ab': '417',
#   'name_last': 'Cain'},
#  {'gidp': '15',
#   'sac': '0',
#   'np': '1976',
#   'name_display_first_last': 'Manny Machado',
#   'pos': '3B',
#   'rank': '13',
#   'tb': '268',
#   'team_brief': 'Dodgers',
#   'sport_id': '1',
#   'name_display_last_init': 'Machado, M',
#   'bb': '60',
#   'avg': '.306',
#   'slg': '.547',
#   'ops': '.929',
#   'hbp': '2',
#   'team_abbrev': 'LAD',
#   'so': '83',
#   'league_id': '104',
#   'sf': '3',
#   'team': 'lan',
#   'league': 'NL',
#   'cs': '1',
#   'sb': '13',
#   'go_ao': '0.76',
#   'last_name': 'Machado',
#   'player_id': '592518',
#   'ibb': '16',
#   'player_qualifier': '555',
#   'team_id': '119',
#   'go': '119',
#   'hr': '29',
#   'minimum_qualifier': '394',
#   'gdp': '15',
#   'name_display_roster': 'Machado, Manny',
#   'qualifies': 'Y',
#   'rbi': '77',
#   'name_first': 'Manny',
#   'bats': 'R',
#   'xbh': '58',
#   'g': '127',
#   'd': '27',
#   'team_name': 'Los Angeles Dodgers',
#   'sport': 'MLB',
#   'tpa': '555',
#   'name_display_last_first': 'Machado, Manny',
#   'h': '150',
#   'obp': '.382',
#   't': '2',
#   'ao': '156',
#   'r': '64',
#   'ab': '490',
#   'name_last': 'Machado'},
#  {'gidp': '10',
#   'sac': '0',
#   'np': '1814',
#   'name_display_first_last': 'David Peralta',
#   'pos': 'LF',
#   'rank': '14',
#   'tb': '241',
#   'team_brief': 'D-backs',
#   'sport_id': '1',
#   'name_display_last_init': 'Peralta, D',
#   'bb': '38',
#   'avg': '.305',
#   'slg': '.544',
#   'ops': '.908',
#   'hbp': '4',
#   'team_abbrev': 'ARI',
#   'so': '96',
#   'league_id': '104',
#   'sf': '1',
#   'team': 'ari',
#   'league': 'NL',
#   'cs': '0',
#   'sb': '2',
#   'go_ao': '1.56',
#   'last_name': 'Peralta',
#   'player_id': '444482',
#   'ibb': '3',
#   'player_qualifier': '486',
#   'team_id': '109',
#   'go': '136',
#   'hr': '24',
#   'minimum_qualifier': '391',
#   'gdp': '10',
#   'name_display_roster': 'Peralta, David',
#   'qualifies': 'Y',
#   'rbi': '68',
#   'name_first': 'David',
#   'bats': 'L',
#   'xbh': '53',
#   'g': '113',
#   'd': '24',
#   'team_name': 'Arizona Diamondbacks',
#   'sport': 'MLB',
#   'tpa': '486',
#   'name_display_last_first': 'Peralta, David',
#   'h': '135',
#   'obp': '.364',
#   't': '5',
#   'ao': '87',
#   'r': '63',
#   'ab': '443',
#   'name_last': 'Peralta'},
#  {'gidp': '10',
#   'sac': '0',
#   'np': '1651',
#   'name_display_first_last': 'Corey Dickerson',
#   'pos': 'LF',
#   'rank': '15',
#   'tb': '197',
#   'team_brief': 'Pirates',
#   'sport_id': '1',
#   'name_display_last_init': 'Dickerson, C',
#   'bb': '17',
#   'avg': '.304',
#   'slg': '.476',
#   'ops': '.811',
#   'hbp': '4',
#   'team_abbrev': 'PIT',
#   'so': '62',
#   'league_id': '104',
#   'sf': '4',
#   'team': 'pit',
#   'league': 'NL',
#   'cs': '3',
#   'sb': '7',
#   'go_ao': '0.75',
#   'last_name': 'Dickerson',
#   'player_id': '572816',
#   'ibb': '3',
#   'player_qualifier': '439',
#   'team_id': '134',
#   'go': '103',
#   'hr': '11',
#   'minimum_qualifier': '397',
#   'gdp': '10',
#   'name_display_roster': 'Dickerson, Corey',
#   'qualifies': 'Y',
#   'rbi': '46',
#   'name_first': 'Corey',
#   'bats': 'L',
#   'xbh': '43',
#   'g': '109',
#   'd': '26',
#   'team_name': 'Pittsburgh Pirates',
#   'sport': 'MLB',
#   'tpa': '439',
#   'name_display_last_first': 'Dickerson, Corey',
#   'h': '126',
#   'obp': '.335',
#   't': '6',
#   'ao': '137',
#   'r': '53',
#   'ab': '414',
#   'name_last': 'Dickerson'},
#  {'gidp': '9',
#   'sac': '7',
#   'np': '1570',
#   'name_display_first_last': 'Mallex Smith',
#   'pos': 'CF',
#   'rank': '16',
#   'tb': '157',
#   'team_brief': 'Rays',
#   'sport_id': '1',
#   'name_display_last_init': 'Smith, M',
#   'bb': '38',
#   'avg': '.304',
#   'slg': '.425',
#   'ops': '.800',
#   'hbp': '5',
#   'team_abbrev': 'TB',
#   'so': '77',
#   'league_id': '103',
#   'sf': '2',
#   'team': 'tba',
#   'league': 'AL',
#   'cs': '9',
#   'sb': '26',
#   'go_ao': '1.33',
#   'last_name': 'Smith',
#   'player_id': '605480',
#   'ibb': '0',
#   'player_qualifier': '421',
#   'team_id': '139',
#   'go': '113',
#   'hr': '2',
#   'minimum_qualifier': '394',
#   'gdp': '9',
#   'name_display_roster': 'Smith, Mallex',
#   'qualifies': 'Y',
#   'rbi': '31',
#   'name_first': 'Mallex',
#   'bats': 'L',
#   'xbh': '32',
#   'g': '115',
#   'd': '21',
#   'team_name': 'Tampa Bay Rays',
#   'sport': 'MLB',
#   'tpa': '421',
#   'name_display_last_first': 'Smith, Mallex',
#   'h': '112',
#   'obp': '.374',
#   't': '9',
#   'ao': '85',
#   'r': '50',
#   'ab': '369',
#   'name_last': 'Smith'},
#  {'gidp': '10',
#   'sac': '2',
#   'np': '2092',
#   'name_display_first_last': 'Whit Merrifield',
#   'pos': '2B',
#   'rank': '17',
#   'tb': '208',
#   'team_brief': 'Royals',
#   'sport_id': '1',
#   'name_display_last_init': 'Merrifield, W',
#   'bb': '49',
#   'avg': '.302',
#   'slg': '.431',
#   'ops': '.801',
#   'hbp': '6',
#   'team_abbrev': 'KC',
#   'so': '91',
#   'league_id': '103',
#   'sf': '4',
#   'team': 'kca',
#   'league': 'AL',
#   'cs': '8',
#   'sb': '27',
#   'go_ao': '0.67',
#   'last_name': 'Merrifield',
#   'player_id': '593160',
#   'ibb': '2',
#   'player_qualifier': '544',
#   'team_id': '118',
#   'go': '105',
#   'hr': '9',
#   'minimum_qualifier': '394',
#   'gdp': '10',
#   'name_display_roster': 'Merrifield, Whit',
#   'qualifies': 'Y',
#   'rbi': '44',
#   'name_first': 'Whit',
#   'bats': 'R',
#   'xbh': '43',
#   'g': '123',
#   'd': '33',
#   'team_name': 'Kansas City Royals',
#   'sport': 'MLB',
#   'tpa': '544',
#   'name_display_last_first': 'Merrifield, Whit',
#   'h': '146',
#   'obp': '.371',
#   't': '1',
#   'ao': '157',
#   'r': '59',
#   'ab': '483',
#   'name_last': 'Merrifield'},
#  {'gidp': '12',
#   'sac': '1',
#   'np': '1800',
#   'name_display_first_last': 'Michael Brantley',
#   'pos': 'LF',
#   'rank': '18',
#   'tb': '214',
#   'team_brief': 'Indians',
#   'sport_id': '1',
#   'name_display_last_init': 'Brantley, M',
#   'bb': '39',
#   'avg': '.301',
#   'slg': '.470',
#   'ops': '.827',
#   'hbp': '3',
#   'team_abbrev': 'CLE',
#   'so': '40',
#   'league_id': '103',
#   'sf': '5',
#   'team': 'cle',
#   'league': 'AL',
#   'cs': '3',
#   'sb': '8',
#   'go_ao': '1.23',
#   'last_name': 'Brantley',
#   'player_id': '488726',
#   'ibb': '0',
#   'player_qualifier': '504',
#   'team_id': '114',
#   'go': '163',
#   'hr': '14',
#   'minimum_qualifier': '391',
#   'gdp': '12',
#   'name_display_roster': 'Brantley, Michael',
#   'qualifies': 'Y',
#   'rbi': '68',
#   'name_first': 'Michael',
#   'bats': 'L',
#   'xbh': '47',
#   'g': '114',
#   'd': '31',
#   'team_name': 'Cleveland Indians',
#   'sport': 'MLB',
#   'tpa': '504',
#   'name_display_last_first': 'Brantley, Michael',
#   'h': '137',
#   'obp': '.357',
#   't': '2',
#   'ao': '133',
#   'r': '73',
#   'ab': '455',
#   'name_last': 'Brantley'},
#  {'gidp': '6',
#   'sac': '0',
#   'np': '2110',
#   'name_display_first_last': 'Andrew Benintendi',
#   'pos': 'LF',
#   'rank': '19',
#   'tb': '231',
#   'team_brief': 'Red Sox',
#   'sport_id': '1',
#   'name_display_last_init': 'Benintendi, A',
#   'bb': '61',
#   'avg': '.299',
#   'slg': '.497',
#   'ops': '.875',
#   'hbp': '2',
#   'team_abbrev': 'BOS',
#   'so': '87',
#   'league_id': '103',
#   'sf': '6',
#   'team': 'bos',
#   'league': 'AL',
#   'cs': '2',
#   'sb': '20',
#   'go_ao': '1.09',
#   'last_name': 'Benintendi',
#   'player_id': '643217',
#   'ibb': '1',
#   'player_qualifier': '534',
#   'team_id': '111',
#   'go': '131',
#   'hr': '15',
#   'minimum_qualifier': '397',
#   'gdp': '6',
#   'name_display_roster': 'Benintendi, Andrew',
#   'qualifies': 'Y',
#   'rbi': '74',
#   'name_first': 'Andrew',
#   'bats': 'L',
#   'xbh': '56',
#   'g': '120',
#   'd': '35',
#   'team_name': 'Boston Red Sox',
#   'sport': 'MLB',
#   'tpa': '534',
#   'name_display_last_first': 'Benintendi, Andrew',
#   'h': '139',
#   'obp': '.378',
#   't': '6',
#   'ao': '120',
#   'r': '89',
#   'ab': '465',
#   'name_last': 'Benintendi'},
#  {'gidp': '14',
#   'sac': '1',
#   'np': '1544',
#   'name_display_first_last': 'Andrelton Simmons',
#   'pos': 'SS',
#   'rank': '20',
#   'tb': '182',
#   'team_brief': 'Angels',
#   'sport_id': '1',
#   'name_display_last_init': 'Simmons, A',
#   'bb': '30',
#   'avg': '.299',
#   'slg': '.421',
#   'ops': '.769',
#   'hbp': '5',
#   'team_abbrev': 'LAA',
#   'so': '28',
#   'league_id': '103',
#   'sf': '4',
#   'team': 'ana',
#   'league': 'AL',
#   'cs': '2',
#   'sb': '7',
#   'go_ao': '1.13',
#   'last_name': 'Simmons',
#   'player_id': '592743',
#   'ibb': '2',
#   'player_qualifier': '472',
#   'team_id': '108',
#   'go': '156',
#   'hr': '8',
#   'minimum_qualifier': '394',
#   'gdp': '14',
#   'name_display_roster': 'Simmons, Andrelton',
#   'qualifies': 'Y',
#   'rbi': '57',
#   'name_first': 'Andrelton',
#   'bats': 'R',
#   'xbh': '34',
#   'g': '114',
#   'd': '23',
#   'team_name': 'Los Angeles Angels',
#   'sport': 'MLB',
#   'tpa': '472',
#   'name_display_last_first': 'Simmons, Andrelton',
#   'h': '129',
#   'obp': '.348',
#   't': '3',
#   'ao': '138',
#   'r': '57',
#   'ab': '432',
#   'name_last': 'Simmons'},
#  {'gidp': '2',
#   'sac': '0',
#   'np': '2400',
#   'name_display_first_last': 'Jose Ramirez',
#   'pos': '3B',
#   'rank': '21',
#   'tb': '285',
#   'team_brief': 'Indians',
#   'sport_id': '1',
#   'name_display_last_init': 'Ramirez, J',
#   'bb': '84',
#   'avg': '.298',
#   'slg': '.624',
#   'ops': '1.033',
#   'hbp': '5',
#   'team_abbrev': 'CLE',
#   'so': '59',
#   'league_id': '103',
#   'sf': '3',
#   'team': 'cle',
#   'league': 'AL',
#   'cs': '5',
#   'sb': '28',
#   'go_ao': '0.64',
#   'last_name': 'Ramirez',
#   'player_id': '608070',
#   'ibb': '14',
#   'player_qualifier': '549',
#   'team_id': '114',
#   'go': '104',
#   'hr': '37',
#   'minimum_qualifier': '391',
#   'gdp': '2',
#   'name_display_roster': 'Ramirez, Jose',
#   'qualifies': 'Y',
#   'rbi': '91',
#   'name_first': 'Jose',
#   'bats': 'S',
#   'xbh': '72',
#   'g': '124',
#   'd': '32',
#   'team_name': 'Cleveland Indians',
#   'sport': 'MLB',
#   'tpa': '549',
#   'name_display_last_first': 'Ramirez, Jose',
#   'h': '136',
#   'obp': '.410',
#   't': '3',
#   'ao': '163',
#   'r': '87',
#   'ab': '457',
#   'name_last': 'Ramirez'},
#  {'gidp': '15',
#   'sac': '0',
#   'np': '1861',
#   'name_display_first_last': 'Eugenio Suarez',
#   'pos': '3B',
#   'rank': '22',
#   'tb': '230',
#   'team_brief': 'Reds',
#   'sport_id': '1',
#   'name_display_last_init': 'Suarez, E',
#   'bb': '49',
#   'avg': '.297',
#   'slg': '.560',
#   'ops': '.937',
#   'hbp': '8',
#   'team_abbrev': 'CIN',
#   'so': '108',
#   'league_id': '104',
#   'sf': '6',
#   'team': 'cin',
#   'league': 'NL',
#   'cs': '0',
#   'sb': '1',
#   'go_ao': '0.96',
#   'last_name': 'Suarez',
#   'player_id': '553993',
#   'ibb': '5',
#   'player_qualifier': '474',
#   'team_id': '113',
#   'go': '99',
#   'hr': '28',
#   'minimum_qualifier': '394',
#   'gdp': '15',
#   'name_display_roster': 'Suarez, Eugenio',
#   'qualifies': 'Y',
#   'rbi': '92',
#   'name_first': 'Eugenio',
#   'bats': 'R',
#   'xbh': '50',
#   'g': '109',
#   'd': '20',
#   'team_name': 'Cincinnati Reds',
#   'sport': 'MLB',
#   'tpa': '474',
#   'name_display_last_first': 'Suarez, Eugenio',
#   'h': '122',
#   'obp': '.378',
#   't': '2',
#   'ao': '103',
#   'r': '66',
#   'ab': '411',
#   'name_last': 'Suarez'},
#  {'gidp': '7',
#   'sac': '0',
#   'np': '1651',
#   'name_display_first_last': 'Miguel Andujar',
#   'pos': '3B',
#   'rank': '23',
#   'tb': '230',
#   'team_brief': 'Yankees',
#   'sport_id': '1',
#   'name_display_last_init': 'Andujar, M',
#   'bb': '19',
#   'avg': '.295',
#   'slg': '.523',
#   'ops': '.850',
#   'hbp': '3',
#   'team_abbrev': 'NYY',
#   'so': '80',
#   'league_id': '103',
#   'sf': '3',
#   'team': 'nya',
#   'league': 'AL',
#   'cs': '0',
#   'sb': '2',
#   'go_ao': '1.22',
#   'last_name': 'Andujar',
#   'player_id': '609280',
#   'ibb': '2',
#   'player_qualifier': '465',
#   'team_id': '147',
#   'go': '132',
#   'hr': '20',
#   'minimum_qualifier': '391',
#   'gdp': '7',
#   'name_display_roster': 'Andujar, Miguel',
#   'qualifies': 'Y',
#   'rbi': '66',
#   'name_first': 'Miguel',
#   'bats': 'R',
#   'xbh': '58',
#   'g': '115',
#   'd': '36',
#   'team_name': 'New York Yankees',
#   'sport': 'MLB',
#   'tpa': '465',
#   'name_display_last_first': 'Andujar, Miguel',
#   'h': '130',
#   'obp': '.327',
#   't': '2',
#   'ao': '108',
#   'r': '64',
#   'ab': '440',
#   'name_last': 'Andujar'},
#  {'gidp': '4',
#   'sac': '0',
#   'np': '2361',
#   'name_display_first_last': 'Paul Goldschmidt',
#   'pos': '1B',
#   'rank': '24',
#   'tb': '256',
#   'team_brief': 'D-backs',
#   'sport_id': '1',
#   'name_display_last_init': 'Goldschmidt, P',
#   'bb': '76',
#   'avg': '.293',
#   'slg': '.544',
#   'ops': '.941',
#   'hbp': '6',
#   'team_abbrev': 'ARI',
#   'so': '139',
#   'league_id': '104',
#   'sf': '0',
#   'team': 'ari',
#   'league': 'NL',
#   'cs': '3',
#   'sb': '5',
#   'go_ao': '1.00',
#   'last_name': 'Goldschmidt',
#   'player_id': '502671',
#   'ibb': '7',
#   'player_qualifier': '553',
#   'team_id': '109',
#   'go': '99',
#   'hr': '28',
#   'minimum_qualifier': '391',
#   'gdp': '4',
#   'name_display_roster': 'Goldschmidt, Paul',
#   'qualifies': 'Y',
#   'rbi': '71',
#   'name_first': 'Paul',
#   'bats': 'R',
#   'xbh': '58',
#   'g': '124',
#   'd': '26',
#   'team_name': 'Arizona Diamondbacks',
#   'sport': 'MLB',
#   'tpa': '553',
#   'name_display_last_first': 'Goldschmidt, Paul',
#   'h': '138',
#   'obp': '.398',
#   't': '4',
#   'ao': '99',
#   'r': '78',
#   'ab': '471',
#   'name_last': 'Goldschmidt'},
#  {'gidp': '3',
#   'sac': '0',
#   'np': '1757',
#   'name_display_first_last': 'Anthony Rendon',
#   'pos': '3B',
#   'rank': '25',
#   'tb': '193',
#   'team_brief': 'Nationals',
#   'sport_id': '1',
#   'name_display_last_init': 'Rendon, A',
#   'bb': '38',
#   'avg': '.293',
#   'slg': '.500',
#   'ops': '.853',
#   'hbp': '2',
#   'team_abbrev': 'WSH',
#   'so': '66',
#   'league_id': '104',
#   'sf': '7',
#   'team': 'was',
#   'league': 'NL',
#   'cs': '1',
#   'sb': '1',
#   'go_ao': '0.58',
#   'last_name': 'Rendon',
#   'player_id': '543685',
#   'ibb': '4',
#   'player_qualifier': '433',
#   'team_id': '120',
#   'go': '80',
#   'hr': '16',
#   'minimum_qualifier': '394',
#   'gdp': '3',
#   'name_display_roster': 'Rendon, Anthony',
#   'qualifies': 'Y',
#   'rbi': '61',
#   'name_first': 'Anthony',
#   'bats': 'R',
#   'xbh': '47',
#   'g': '100',
#   'd': '30',
#   'team_name': 'Washington Nationals',
#   'sport': 'MLB',
#   'tpa': '433',
#   'name_display_last_first': 'Rendon, Anthony',
#   'h': '113',
#   'obp': '.353',
#   't': '1',
#   'ao': '137',
#   'r': '58',
#   'ab': '386',
#   'name_last': 'Rendon'},
#  {'gidp': '12',
#   'sac': '0',
#   'np': '1651',
#   'name_display_first_last': 'Matt Duffy',
#   'pos': '3B',
#   'rank': '26',
#   'tb': '151',
#   'team_brief': 'Rays',
#   'sport_id': '1',
#   'name_display_last_init': 'Duffy, M',
#   'bb': '31',
#   'avg': '.293',
#   'slg': '.368',
#   'ops': '.719',
#   'hbp': '6',
#   'team_abbrev': 'TB',
#   'so': '73',
#   'league_id': '103',
#   'sf': '1',
#   'team': 'tba',
#   'league': 'AL',
#   'cs': '5',
#   'sb': '9',
#   'go_ao': '1.61',
#   'last_name': 'Duffy',
#   'player_id': '622110',
#   'ibb': '1',
#   'player_qualifier': '448',
#   'team_id': '139',
#   'go': '142',
#   'hr': '4',
#   'minimum_qualifier': '394',
#   'gdp': '12',
#   'name_display_roster': 'Duffy, Matt',
#   'qualifies': 'Y',
#   'rbi': '33',
#   'name_first': 'Matt',
#   'bats': 'R',
#   'xbh': '22',
#   'g': '106',
#   'd': '17',
#   'team_name': 'Tampa Bay Rays',
#   'sport': 'MLB',
#   'tpa': '448',
#   'name_display_last_first': 'Duffy, Matt',
#   'h': '120',
#   'obp': '.350',
#   't': '1',
#   'ao': '88',
#   'r': '42',
#   'ab': '410',
#   'name_last': 'Duffy'},
#  {'gidp': '11',
#   'sac': '7',
#   'np': '1787',
#   'name_display_first_last': 'Jose Peraza',
#   'pos': 'SS',
#   'rank': '27',
#   'tb': '202',
#   'team_brief': 'Reds',
#   'sport_id': '1',
#   'name_display_last_init': 'Peraza, J',
#   'bb': '28',
#   'avg': '.292',
#   'slg': '.410',
#   'ops': '.744',
#   'hbp': '5',
#   'team_abbrev': 'CIN',
#   'so': '55',
#   'league_id': '104',
#   'sf': '3',
#   'team': 'cin',
#   'league': 'NL',
#   'cs': '6',
#   'sb': '19',
#   'go_ao': '0.80',
#   'last_name': 'Peraza',
#   'player_id': '606299',
#   'ibb': '4',
#   'player_qualifier': '536',
#   'team_id': '113',
#   'go': '140',
#   'hr': '8',
#   'minimum_qualifier': '394',
#   'gdp': '11',
#   'name_display_roster': 'Peraza, Jose',
#   'qualifies': 'Y',
#   'rbi': '42',
#   'name_first': 'Jose',
#   'bats': 'R',
#   'xbh': '38',
#   'g': '124',
#   'd': '26',
#   'team_name': 'Cincinnati Reds',
#   'sport': 'MLB',
#   'tpa': '536',
#   'name_display_last_first': 'Peraza, Jose',
#   'h': '144',
#   'obp': '.335',
#   't': '4',
#   'ao': '175',
#   'r': '67',
#   'ab': '493',
#   'name_last': 'Peraza'},
#  {'gidp': '6',
#   'sac': '0',
#   'np': '1912',
#   'name_display_first_last': 'Nicholas Castellanos',
#   'pos': 'RF',
#   'rank': '28',
#   'tb': '239',
#   'team_brief': 'Tigers',
#   'sport_id': '1',
#   'name_display_last_init': 'Castellanos, N',
#   'bb': '35',
#   'avg': '.292',
#   'slg': '.491',
#   'ops': '.836',
#   'hbp': '5',
#   'team_abbrev': 'DET',
#   'so': '120',
#   'league_id': '103',
#   'sf': '0',
#   'team': 'det',
#   'league': 'AL',
#   'cs': '1',
#   'sb': '2',
#   'go_ao': '0.85',
#   'last_name': 'Castellanos',
#   'player_id': '592206',
#   'ibb': '3',
#   'player_qualifier': '527',
#   'team_id': '116',
#   'go': '106',
#   'hr': '18',
#   'minimum_qualifier': '394',
#   'gdp': '6',
#   'name_display_roster': 'Castellanos, Nicholas',
#   'qualifies': 'Y',
#   'rbi': '70',
#   'name_first': 'Nicholas',
#   'bats': 'R',
#   'xbh': '57',
#   'g': '122',
#   'd': '35',
#   'team_name': 'Detroit Tigers',
#   'sport': 'MLB',
#   'tpa': '527',
#   'name_display_last_first': 'Castellanos, Nicholas',
#   'h': '142',
#   'obp': '.345',
#   't': '4',
#   'ao': '125',
#   'r': '68',
#   'ab': '487',
#   'name_last': 'Castellanos'},
#  {'gidp': '10',
#   'sac': '1',
#   'np': '1637',
#   'name_display_first_last': 'Javier Baez',
#   'pos': '2B',
#   'rank': '29',
#   'tb': '262',
#   'team_brief': 'Cubs',
#   'sport_id': '1',
#   'name_display_last_init': 'Baez, J',
#   'bb': '18',
#   'avg': '.292',
#   'slg': '.566',
#   'ops': '.888',
#   'hbp': '5',
#   'team_abbrev': 'CHC',
#   'so': '116',
#   'league_id': '104',
#   'sf': '4',
#   'team': 'chn',
#   'league': 'NL',
#   'cs': '5',
#   'sb': '20',
#   'go_ao': '1.44',
#   'last_name': 'Baez',
#   'player_id': '595879',
#   'ibb': '7',
#   'player_qualifier': '491',
#   'team_id': '112',
#   'go': '134',
#   'hr': '26',
#   'minimum_qualifier': '388',
#   'gdp': '10',
#   'name_display_roster': 'Baez, Javier',
#   'qualifies': 'Y',
#   'rbi': '92',
#   'name_first': 'Javier',
#   'bats': 'R',
#   'xbh': '67',
#   'g': '123',
#   'd': '33',
#   'team_name': 'Chicago Cubs',
#   'sport': 'MLB',
#   'tpa': '491',
#   'name_display_last_first': 'Baez, Javier',
#   'h': '135',
#   'obp': '.322',
#   't': '8',
#   'ao': '93',
#   'r': '75',
#   'ab': '463',
#   'name_last': 'Baez'},
#  {'gidp': '9',
#   'sac': '0',
#   'np': '2063',
#   'name_display_first_last': 'Trevor Story',
#   'pos': 'SS',
#   'rank': '30',
#   'tb': '260',
#   'team_brief': 'Rockies',
#   'sport_id': '1',
#   'name_display_last_init': 'Story, T',
#   'bb': '38',
#   'avg': '.291',
#   'slg': '.549',
#   'ops': '.896',
#   'hbp': '5',
#   'team_abbrev': 'COL',
#   'so': '131',
#   'league_id': '104',
#   'sf': '4',
#   'team': 'col',
#   'league': 'NL',
#   'cs': '5',
#   'sb': '17',
#   'go_ao': '0.65',
#   'last_name': 'Story',
#   'player_id': '596115',
#   'ibb': '2',
#   'player_qualifier': '521',
#   'team_id': '115',
#   'go': '86',
#   'hr': '26',
#   'minimum_qualifier': '388',
#   'gdp': '9',
#   'name_display_roster': 'Story, Trevor',
#   'qualifies': 'Y',
#   'rbi': '84',
#   'name_first': 'Trevor',
#   'bats': 'R',
#   'xbh': '65',
#   'g': '124',
#   'd': '34',
#   'team_name': 'Colorado Rockies',
#   'sport': 'MLB',
#   'tpa': '521',
#   'name_display_last_first': 'Story, Trevor',
#   'h': '138',
#   'obp': '.347',
#   't': '5',
#   'ao': '132',
#   'r': '65',
#   'ab': '474',
#   'name_last': 'Story'},
#  {'gidp': '10',
#   'sac': '1',
#   'np': '1469',
#   'name_display_first_last': 'Joey Wendle',
#   'pos': '2B',
#   'rank': '31',
#   'tb': '155',
#   'team_brief': 'Rays',
#   'sport_id': '1',
#   'name_display_last_init': 'Wendle, J',
#   'bb': '22',
#   'avg': '.290',
#   'slg': '.425',
#   'ops': '.764',
#   'hbp': '8',
#   'team_abbrev': 'TB',
#   'so': '80',
#   'league_id': '103',
#   'sf': '6',
#   'team': 'tba',
#   'league': 'AL',
#   'cs': '4',
#   'sb': '8',
#   'go_ao': '1.23',
#   'last_name': 'Wendle',
#   'player_id': '621563',
#   'ibb': '1',
#   'player_qualifier': '402',
#   'team_id': '139',
#   'go': '108',
#   'hr': '7',
#   'minimum_qualifier': '394',
#   'gdp': '10',
#   'name_display_roster': 'Wendle, Joey',
#   'qualifies': 'Y',
#   'rbi': '44',
#   'name_first': 'Joey',
#   'bats': 'L',
#   'xbh': '30',
#   'g': '107',
#   'd': '18',
#   'team_name': 'Tampa Bay Rays',
#   'sport': 'MLB',
#   'tpa': '402',
#   'name_display_last_first': 'Wendle, Joey',
#   'h': '106',
#   'obp': '.339',
#   't': '5',
#   'ao': '88',
#   'r': '42',
#   'ab': '365',
#   'name_last': 'Wendle'},
#  {'gidp': '4',
#   'sac': '1',
#   'np': '1928',
#   'name_display_first_last': 'Eddie Rosario',
#   'pos': 'LF',
#   'rank': '32',
#   'tb': '246',
#   'team_brief': 'Twins',
#   'sport_id': '1',
#   'name_display_last_init': 'Rosario, E',
#   'bb': '30',
#   'avg': '.290',
#   'slg': '.488',
#   'ops': '.816',
#   'hbp': '0',
#   'team_abbrev': 'MIN',
#   'so': '95',
#   'league_id': '103',
#   'sf': '2',
#   'team': 'min',
#   'league': 'AL',
#   'cs': '2',
#   'sb': '7',
#   'go_ao': '0.76',
#   'last_name': 'Rosario',
#   'player_id': '592696',
#   'ibb': '5',
#   'player_qualifier': '537',
#   'team_id': '142',
#   'go': '117',
#   'hr': '22',
#   'minimum_qualifier': '391',
#   'gdp': '4',
#   'name_display_roster': 'Rosario, Eddie',
#   'qualifies': 'Y',
#   'rbi': '72',
#   'name_first': 'Eddie',
#   'bats': 'L',
#   'xbh': '54',
#   'g': '124',
#   'd': '30',
#   'team_name': 'Minnesota Twins',
#   'sport': 'MLB',
#   'tpa': '537',
#   'name_display_last_first': 'Rosario, Eddie',
#   'h': '146',
#   'obp': '.328',
#   't': '2',
#   'ao': '153',
#   'r': '80',
#   'ab': '504',
#   'name_last': 'Rosario'},
#  {'gidp': '5',
#   'sac': '3',
#   'np': '2274',
#   'name_display_first_last': 'Francisco Lindor',
#   'pos': 'SS',
#   'rank': '33',
#   'tb': '276',
#   'team_brief': 'Indians',
#   'sport_id': '1',
#   'name_display_last_init': 'Lindor, F',
#   'bb': '60',
#   'avg': '.289',
#   'slg': '.542',
#   'ops': '.911',
#   'hbp': '6',
#   'team_abbrev': 'CLE',
#   'so': '87',
#   'league_id': '103',
#   'sf': '3',
#   'team': 'cle',
#   'league': 'AL',
#   'cs': '8',
#   'sb': '19',
#   'go_ao': '0.88',
#   'last_name': 'Lindor',
#   'player_id': '596019',
#   'ibb': '5',
#   'player_qualifier': '581',
#   'team_id': '114',
#   'go': '134',
#   'hr': '29',
#   'minimum_qualifier': '391',
#   'gdp': '5',
#   'name_display_roster': 'Lindor, Francisco',
#   'qualifies': 'Y',
#   'rbi': '76',
#   'name_first': 'Francisco',
#   'bats': 'S',
#   'xbh': '70',
#   'g': '124',
#   'd': '40',
#   'team_name': 'Cleveland Indians',
#   'sport': 'MLB',
#   'tpa': '581',
#   'name_display_last_first': 'Lindor, Francisco',
#   'h': '147',
#   'obp': '.369',
#   't': '1',
#   'ao': '152',
#   'r': '105',
#   'ab': '509',
#   'name_last': 'Lindor'},
#  {'gidp': '16',
#   'sac': '0',
#   'np': '2008',
#   'name_display_first_last': 'Starlin Castro',
#   'pos': '2B',
#   'rank': '34',
#   'tb': '199',
#   'team_brief': 'Marlins',
#   'sport_id': '1',
#   'name_display_last_init': 'Castro, S',
#   'bb': '41',
#   'avg': '.287',
#   'slg': '.405',
#   'ops': '.744',
#   'hbp': '0',
#   'team_abbrev': 'MIA',
#   'so': '99',
#   'league_id': '104',
#   'sf': '6',
#   'team': 'mia',
#   'league': 'NL',
#   'cs': '2',
#   'sb': '6',
#   'go_ao': '1.33',
#   'last_name': 'Castro',
#   'player_id': '516770',
#   'ibb': '3',
#   'player_qualifier': '538',
#   'team_id': '146',
#   'go': '156',
#   'hr': '10',
#   'minimum_qualifier': '397',
#   'gdp': '16',
#   'name_display_roster': 'Castro, Starlin',
#   'qualifies': 'Y',
#   'rbi': '46',
#   'name_first': 'Starlin',
#   'bats': 'R',
#   'xbh': '37',
#   'g': '125',
#   'd': '26',
#   'team_name': 'Miami Marlins',
#   'sport': 'MLB',
#   'tpa': '538',
#   'name_display_last_first': 'Castro, Starlin',
#   'h': '141',
#   'obp': '.338',
#   't': '1',
#   'ao': '117',
#   'r': '70',
#   'ab': '491',
#   'name_last': 'Castro'},
#  {'gidp': '7',
#   'sac': '0',
#   'np': '1628',
#   'name_display_first_last': 'J.T. Realmuto',
#   'pos': 'C',
#   'rank': '35',
#   'tb': '190',
#   'team_brief': 'Marlins',
#   'sport_id': '1',
#   'name_display_last_init': 'Realmuto, J',
#   'bb': '27',
#   'avg': '.286',
#   'slg': '.495',
#   'ops': '.841',
#   'hbp': '10',
#   'team_abbrev': 'MIA',
#   'so': '79',
#   'league_id': '104',
#   'sf': '3',
#   'team': 'mia',
#   'league': 'NL',
#   'cs': '2',
#   'sb': '1',
#   'go_ao': '0.88',
#   'last_name': 'Realmuto',
#   'player_id': '592663',
#   'ibb': '0',
#   'player_qualifier': '426',
#   'team_id': '146',
#   'go': '96',
#   'hr': '16',
#   'minimum_qualifier': '397',
#   'gdp': '7',
#   'name_display_roster': 'Realmuto, J.T.',
#   'qualifies': 'Y',
#   'rbi': '61',
#   'name_first': 'J.T.',
#   'bats': 'R',
#   'xbh': '45',
#   'g': '98',
#   'd': '26',
#   'team_name': 'Miami Marlins',
#   'sport': 'MLB',
#   'tpa': '426',
#   'name_display_last_first': 'Realmuto, J.T.',
#   'h': '110',
#   'obp': '.347',
#   't': '3',
#   'ao': '109',
#   'r': '59',
#   'ab': '384',
#   'name_last': 'Realmuto'},
#  {'gidp': '14',
#   'sac': '0',
#   'np': '2310',
#   'name_display_first_last': 'Giancarlo Stanton',
#   'pos': 'LF',
#   'rank': '36',
#   'tb': '265',
#   'team_brief': 'Yankees',
#   'sport_id': '1',
#   'name_display_last_init': 'Stanton, G',
#   'bb': '49',
#   'avg': '.286',
#   'slg': '.541',
#   'ops': '.895',
#   'hbp': '8',
#   'team_abbrev': 'NYY',
#   'so': '165',
#   'league_id': '103',
#   'sf': '9',
#   'team': 'nya',
#   'league': 'AL',
#   'cs': '0',
#   'sb': '5',
#   'go_ao': '1.24',
#   'last_name': 'Stanton',
#   'player_id': '519317',
#   'ibb': '4',
#   'player_qualifier': '556',
#   'team_id': '147',
#   'go': '115',
#   'hr': '32',
#   'minimum_qualifier': '391',
#   'gdp': '14',
#   'name_display_roster': 'Stanton, Giancarlo',
#   'qualifies': 'Y',
#   'rbi': '81',
#   'name_first': 'Giancarlo',
#   'bats': 'R',
#   'xbh': '60',
#   'g': '125',
#   'd': '27',
#   'team_name': 'New York Yankees',
#   'sport': 'MLB',
#   'tpa': '556',
#   'name_display_last_first': 'Stanton, Giancarlo',
#   'h': '140',
#   'obp': '.354',
#   't': '1',
#   'ao': '93',
#   'r': '82',
#   'ab': '490',
#   'name_last': 'Stanton'},
#  {'gidp': '8',
#   'sac': '0',
#   'np': '1901',
#   'name_display_first_last': 'Aaron Judge',
#   'pos': 'RF',
#   'rank': '37',
#   'tb': '204',
#   'team_brief': 'Yankees',
#   'sport_id': '1',
#   'name_display_last_init': 'Judge, A',
#   'bb': '68',
#   'avg': '.285',
#   'slg': '.548',
#   'ops': '.947',
#   'hbp': '4',
#   'team_abbrev': 'NYY',
#   'so': '137',
#   'league_id': '103',
#   'sf': '3',
#   'team': 'nya',
#   'league': 'AL',
#   'cs': '3',
#   'sb': '6',
#   'go_ao': '1.22',
#   'last_name': 'Judge',
#   'player_id': '592450',
#   'ibb': '3',
#   'player_qualifier': '447',
#   'team_id': '147',
#   'go': '77',
#   'hr': '26',
#   'minimum_qualifier': '391',
#   'gdp': '8',
#   'name_display_roster': 'Judge, Aaron',
#   'qualifies': 'Y',
#   'rbi': '61',
#   'name_first': 'Aaron',
#   'bats': 'R',
#   'xbh': '46',
#   'g': '99',
#   'd': '20',
#   'team_name': 'New York Yankees',
#   'sport': 'MLB',
#   'tpa': '447',
#   'name_display_last_first': 'Judge, Aaron',
#   'h': '106',
#   'obp': '.398',
#   't': '0',
#   'ao': '63',
#   'r': '70',
#   'ab': '372',
#   'name_last': 'Judge'},
#  {'gidp': '5',
#   'sac': '0',
#   'np': '1453',
#   'name_display_first_last': 'Carlos Gonzalez',
#   'pos': 'RF',
#   'rank': '38',
#   'tb': '173',
#   'team_brief': 'Rockies',
#   'sport_id': '1',
#   'name_display_last_init': 'Gonzalez, C',
#   'bb': '31',
#   'avg': '.285',
#   'slg': '.483',
#   'ops': '.825',
#   'hbp': '1',
#   'team_abbrev': 'COL',
#   'so': '88',
#   'league_id': '104',
#   'sf': '2',
#   'team': 'col',
#   'league': 'NL',
#   'cs': '2',
#   'sb': '4',
#   'go_ao': '1.40',
#   'last_name': 'Gonzalez',
#   'player_id': '471865',
#   'ibb': '4',
#   'player_qualifier': '392',
#   'team_id': '115',
#   'go': '102',
#   'hr': '14',
#   'minimum_qualifier': '388',
#   'gdp': '5',
#   'name_display_roster': 'Gonzalez, Carlos',
#   'qualifies': 'Y',
#   'rbi': '52',
#   'name_first': 'Carlos',
#   'bats': 'L',
#   'xbh': '40',
#   'g': '104',
#   'd': '23',
#   'team_name': 'Colorado Rockies',
#   'sport': 'MLB',
#   'tpa': '392',
#   'name_display_last_first': 'Gonzalez, Carlos',
#   'h': '102',
#   'obp': '.342',
#   't': '3',
#   'ao': '73',
#   'r': '59',
#   'ab': '358',
#   'name_last': 'Gonzalez'},
#  {'gidp': '14',
#   'sac': '0',
#   'np': '2041',
#   'name_display_first_last': 'Joey Votto',
#   'pos': '1B',
#   'rank': '39',
#   'tb': '171',
#   'team_brief': 'Reds',
#   'sport_id': '1',
#   'name_display_last_init': 'Votto, J',
#   'bb': '91',
#   'avg': '.284',
#   'slg': '.419',
#   'ops': '.842',
#   'hbp': '8',
#   'team_abbrev': 'CIN',
#   'so': '81',
#   'league_id': '104',
#   'sf': '2',
#   'team': 'cin',
#   'league': 'NL',
#   'cs': '0',
#   'sb': '1',
#   'go_ao': '1.03',
#   'last_name': 'Votto',
#   'player_id': '458015',
#   'ibb': '6',
#   'player_qualifier': '509',
#   'team_id': '113',
#   'go': '115',
#   'hr': '9',
#   'minimum_qualifier': '394',
#   'gdp': '14',
#   'name_display_roster': 'Votto, Joey',
#   'qualifies': 'Y',
#   'rbi': '55',
#   'name_first': 'Joey',
#   'bats': 'L',
#   'xbh': '35',
#   'g': '118',
#   'd': '24',
#   'team_name': 'Cincinnati Reds',
#   'sport': 'MLB',
#   'tpa': '509',
#   'name_display_last_first': 'Votto, Joey',
#   'h': '116',
#   'obp': '.422',
#   't': '2',
#   'ao': '112',
#   'r': '58',
#   'ab': '408',
#   'name_last': 'Votto'},
#  {'gidp': '12',
#   'sac': '0',
#   'np': '1659',
#   'name_display_first_last': 'Buster Posey',
#   'pos': 'C',
#   'rank': '40',
#   'tb': '151',
#   'team_brief': 'Giants',
#   'sport_id': '1',
#   'name_display_last_init': 'Posey, B',
#   'bb': '43',
#   'avg': '.284',
#   'slg': '.382',
#   'ops': '.739',
#   'hbp': '3',
#   'team_abbrev': 'SF',
#   'so': '53',
#   'league_id': '104',
#   'sf': '2',
#   'team': 'sfn',
#   'league': 'NL',
#   'cs': '2',
#   'sb': '3',
#   'go_ao': '1.28',
#   'last_name': 'Posey',
#   'player_id': '457763',
#   'ibb': '3',
#   'player_qualifier': '443',
#   'team_id': '137',
#   'go': '137',
#   'hr': '5',
#   'minimum_qualifier': '397',
#   'gdp': '12',
#   'name_display_roster': 'Posey, Buster',
#   'qualifies': 'Y',
#   'rbi': '40',
#   'name_first': 'Buster',
#   'bats': 'R',
#   'xbh': '28',
#   'g': '104',
#   'd': '22',
#   'team_name': 'San Francisco Giants',
#   'sport': 'MLB',
#   'tpa': '443',
#   'name_display_last_first': 'Posey, Buster',
#   'h': '112',
#   'obp': '.357',
#   't': '1',
#   'ao': '107',
#   'r': '46',
#   'ab': '395',
#   'name_last': 'Posey'},
#  {'gidp': '10',
#   'sac': '0',
#   'np': '1556',
#   'name_display_first_last': 'Matt Kemp',
#   'pos': 'LF',
#   'rank': '41',
#   'tb': '184',
#   'team_brief': 'Dodgers',
#   'sport_id': '1',
#   'name_display_last_init': 'Kemp, M',
#   'bb': '34',
#   'avg': '.284',
#   'slg': '.474',
#   'ops': '.811',
#   'hbp': '1',
#   'team_abbrev': 'LAD',
#   'so': '97',
#   'league_id': '104',
#   'sf': '7',
#   'team': 'lan',
#   'league': 'NL',
#   'cs': '0',
#   'sb': '0',
#   'go_ao': '0.82',
#   'last_name': 'Kemp',
#   'player_id': '461314',
#   'ibb': '2',
#   'player_qualifier': '430',
#   'team_id': '119',
#   'go': '89',
#   'hr': '18',
#   'minimum_qualifier': '394',
#   'gdp': '10',
#   'name_display_roster': 'Kemp, Matt',
#   'qualifies': 'Y',
#   'rbi': '69',
#   'name_first': 'Matt',
#   'bats': 'R',
#   'xbh': '38',
#   'g': '120',
#   'd': '20',
#   'team_name': 'Los Angeles Dodgers',
#   'sport': 'MLB',
#   'tpa': '430',
#   'name_display_last_first': 'Kemp, Matt',
#   'h': '110',
#   'obp': '.337',
#   't': '0',
#   'ao': '109',
#   'r': '54',
#   'ab': '388',
#   'name_last': 'Kemp'},
#  {'gidp': '8',
#   'sac': '1',
#   'np': '2325',
#   'name_display_first_last': 'Shin-Soo Choo',
#   'pos': 'RF',
#   'rank': '42',
#   'tb': '224',
#   'team_brief': 'Rangers',
#   'sport_id': '1',
#   'name_display_last_init': 'Choo, S',
#   'bb': '80',
#   'avg': '.282',
#   'slg': '.483',
#   'ops': '.877',
#   'hbp': '7',
#   'team_abbrev': 'TEX',
#   'so': '131',
#   'league_id': '103',
#   'sf': '2',
#   'team': 'tex',
#   'league': 'AL',
#   'cs': '1',
#   'sb': '4',
#   'go_ao': '1.60',
#   'last_name': 'Choo',
#   'player_id': '425783',
#   'ibb': '2',
#   'player_qualifier': '554',
#   'team_id': '140',
#   'go': '131',
#   'hr': '21',
#   'minimum_qualifier': '400',
#   'gdp': '8',
#   'name_display_roster': 'Choo, Shin-Soo',
#   'qualifies': 'Y',
#   'rbi': '58',
#   'name_first': 'Shin-Soo',
#   'bats': 'L',
#   'xbh': '50',
#   'g': '119',
#   'd': '28',
#   'team_name': 'Texas Rangers',
#   'sport': 'MLB',
#   'tpa': '554',
#   'name_display_last_first': 'Choo, Shin-Soo',
#   'h': '131',
#   'obp': '.394',
#   't': '1',
#   'ao': '82',
#   'r': '73',
#   'ab': '464',
#   'name_last': 'Choo'},
#  {'gidp': '12',
#   'sac': '0',
#   'np': '1849',
#   'name_display_first_last': 'Xander Bogaerts',
#   'pos': 'SS',
#   'rank': '43',
#   'tb': '214',
#   'team_brief': 'Red Sox',
#   'sport_id': '1',
#   'name_display_last_init': 'Bogaerts, X',
#   'bb': '43',
#   'avg': '.282',
#   'slg': '.530',
#   'ops': '.886',
#   'hbp': '6',
#   'team_abbrev': 'BOS',
#   'so': '77',
#   'league_id': '103',
#   'sf': '4',
#   'team': 'bos',
#   'league': 'AL',
#   'cs': '2',
#   'sb': '5',
#   'go_ao': '1.22',
#   'last_name': 'Bogaerts',
#   'player_id': '593428',
#   'ibb': '4',
#   'player_qualifier': '457',
#   'team_id': '111',
#   'go': '126',
#   'hr': '19',
#   'minimum_qualifier': '397',
#   'gdp': '12',
#   'name_display_roster': 'Bogaerts, Xander',
#   'qualifies': 'Y',
#   'rbi': '80',
#   'name_first': 'Xander',
#   'bats': 'R',
#   'xbh': '59',
#   'g': '106',
#   'd': '37',
#   'team_name': 'Boston Red Sox',
#   'sport': 'MLB',
#   'tpa': '457',
#   'name_display_last_first': 'Bogaerts, Xander',
#   'h': '114',
#   'obp': '.357',
#   't': '3',
#   'ao': '103',
#   'r': '61',
#   'ab': '404',
#   'name_last': 'Bogaerts'},
#  {'gidp': '20',
#   'sac': '0',
#   'np': '1496',
#   'name_display_first_last': 'Yuli Gurriel',
#   'pos': '1B',
#   'rank': '44',
#   'tb': '172',
#   'team_brief': 'Astros',
#   'sport_id': '1',
#   'name_display_last_init': 'Gurriel, Y',
#   'bb': '18',
#   'avg': '.282',
#   'slg': '.408',
#   'ops': '.721',
#   'hbp': '4',
#   'team_abbrev': 'HOU',
#   'so': '49',
#   'league_id': '103',
#   'sf': '6',
#   'team': 'hou',
#   'league': 'AL',
#   'cs': '1',
#   'sb': '5',
#   'go_ao': '1.00',
#   'last_name': 'Gurriel',
#   'player_id': '493329',
#   'ibb': '0',
#   'player_qualifier': '450',
#   'team_id': '117',
#   'go': '140',
#   'hr': '8',
#   'minimum_qualifier': '394',
#   'gdp': '20',
#   'name_display_roster': 'Gurriel, Yuli',
#   'qualifies': 'Y',
#   'rbi': '62',
#   'name_first': 'Yuli',
#   'bats': 'R',
#   'xbh': '36',
#   'g': '106',
#   'd': '27',
#   'team_name': 'Houston Astros',
#   'sport': 'MLB',
#   'tpa': '450',
#   'name_display_last_first': 'Gurriel, Yuli',
#   'h': '119',
#   'obp': '.313',
#   't': '1',
#   'ao': '140',
#   'r': '56',
#   'ab': '422',
#   'name_last': 'Gurriel'},
#  {'gidp': '13',
#   'sac': '0',
#   'np': '2257',
#   'name_display_first_last': 'Alex Bregman',
#   'pos': '3B',
#   'rank': '45',
#   'tb': '246',
#   'team_brief': 'Astros',
#   'sport_id': '1',
#   'name_display_last_init': 'Bregman, A',
#   'bb': '72',
#   'avg': '.282',
#   'slg': '.517',
#   'ops': '.901',
#   'hbp': '9',
#   'team_abbrev': 'HOU',
#   'so': '68',
#   'league_id': '103',
#   'sf': '3',
#   'team': 'hou',
#   'league': 'AL',
#   'cs': '4',
#   'sb': '9',
#   'go_ao': '0.73',
#   'last_name': 'Bregman',
#   'player_id': '608324',
#   'ibb': '0',
#   'player_qualifier': '560',
#   'team_id': '117',
#   'go': '122',
#   'hr': '24',
#   'minimum_qualifier': '394',
#   'gdp': '13',
#   'name_display_roster': 'Bregman, Alex',
#   'qualifies': 'Y',
#   'rbi': '78',
#   'name_first': 'Alex',
#   'bats': 'R',
#   'xbh': '63',
#   'g': '124',
#   'd': '38',
#   'team_name': 'Houston Astros',
#   'sport': 'MLB',
#   'tpa': '560',
#   'name_display_last_first': 'Bregman, Alex',
#   'h': '134',
#   'obp': '.384',
#   't': '1',
#   'ao': '168',
#   'r': '82',
#   'ab': '476',
#   'name_last': 'Bregman'},
#  {'gidp': '17',
#   'sac': '0',
#   'np': '1766',
#   'name_display_first_last': 'Adam Jones',
#   'pos': 'CF',
#   'rank': '46',
#   'tb': '202',
#   'team_brief': 'Orioles',
#   'sport_id': '1',
#   'name_display_last_init': 'Jones, A',
#   'bb': '21',
#   'avg': '.281',
#   'slg': '.431',
#   'ops': '.746',
#   'hbp': '3',
#   'team_abbrev': 'BAL',
#   'so': '77',
#   'league_id': '103',
#   'sf': '2',
#   'team': 'bal',
#   'league': 'AL',
#   'cs': '0',
#   'sb': '4',
#   'go_ao': '1.07',
#   'last_name': 'Jones',
#   'player_id': '430945',
#   'ibb': '0',
#   'player_qualifier': '495',
#   'team_id': '110',
#   'go': '144',
#   'hr': '13',
#   'minimum_qualifier': '394',
#   'gdp': '17',
#   'name_display_roster': 'Jones, Adam',
#   'qualifies': 'Y',
#   'rbi': '49',
#   'name_first': 'Adam',
#   'bats': 'R',
#   'xbh': '44',
#   'g': '117',
#   'd': '31',
#   'team_name': 'Baltimore Orioles',
#   'sport': 'MLB',
#   'tpa': '495',
#   'name_display_last_first': 'Jones, Adam',
#   'h': '132',
#   'obp': '.315',
#   't': '0',
#   'ao': '135',
#   'r': '46',
#   'ab': '469',
#   'name_last': 'Jones'},
#  {'gidp': '12',
#   'sac': '0',
#   'np': '1468',
#   'name_display_first_last': 'Maikel Franco',
#   'pos': '3B',
#   'rank': '47',
#   'tb': '188',
#   'team_brief': 'Phillies',
#   'sport_id': '1',
#   'name_display_last_init': 'Franco, M',
#   'bb': '25',
#   'avg': '.281',
#   'slg': '.485',
#   'ops': '.807',
#   'hbp': '0',
#   'team_abbrev': 'PHI',
#   'so': '56',
#   'league_id': '104',
#   'sf': '3',
#   'team': 'phi',
#   'league': 'NL',
#   'cs': '0',
#   'sb': '1',
#   'go_ao': '1.27',
#   'last_name': 'Franco',
#   'player_id': '596748',
#   'ibb': '7',
#   'player_qualifier': '416',
#   'team_id': '143',
#   'go': '133',
#   'hr': '20',
#   'minimum_qualifier': '391',
#   'gdp': '12',
#   'name_display_roster': 'Franco, Maikel',
#   'qualifies': 'Y',
#   'rbi': '62',
#   'name_first': 'Maikel',
#   'bats': 'R',
#   'xbh': '38',
#   'g': '114',
#   'd': '17',
#   'team_name': 'Philadelphia Phillies',
#   'sport': 'MLB',
#   'tpa': '416',
#   'name_display_last_first': 'Franco, Maikel',
#   'h': '109',
#   'obp': '.322',
#   't': '1',
#   'ao': '105',
#   'r': '43',
#   'ab': '388',
#   'name_last': 'Franco'},
#  {'gidp': '10',
#   'sac': '0',
#   'np': '1930',
#   'name_display_first_last': 'Eduardo Escobar',
#   'pos': '3B',
#   'rank': '48',
#   'tb': '227',
#   'team_brief': 'D-backs',
#   'sport_id': '1',
#   'name_display_last_init': 'Escobar, E',
#   'bb': '43',
#   'avg': '.281',
#   'slg': '.514',
#   'ops': '.858',
#   'hbp': '3',
#   'team_abbrev': 'ARI',
#   'so': '102',
#   'league_id': '104',
#   'sf': '6',
#   'team': 'ari',
#   'league': 'NL',
#   'cs': '3',
#   'sb': '1',
#   'go_ao': '0.67',
#   'last_name': 'Escobar',
#   'player_id': '500871',
#   'ibb': '7',
#   'player_qualifier': '494',
#   'team_id': '109',
#   'go': '93',
#   'hr': '18',
#   'minimum_qualifier': '391',
#   'gdp': '10',
#   'name_display_roster': 'Escobar, Eduardo',
#   'qualifies': 'Y',
#   'rbi': '75',
#   'name_first': 'Eduardo',
#   'bats': 'S',
#   'xbh': '64',
#   'g': '117',
#   'd': '43',
#   'team_name': 'Arizona Diamondbacks',
#   'sport': 'MLB',
#   'tpa': '494',
#   'name_display_last_first': 'Escobar, Eduardo',
#   'h': '124',
#   'obp': '.344',
#   't': '3',
#   'ao': '139',
#   'r': '60',
#   'ab': '442',
#   'name_last': 'Escobar'},
#  {'gidp': '14',
#   'sac': '0',
#   'np': '1857',
#   'name_display_first_last': 'Jesus Aguilar',
#   'pos': '1B',
#   'rank': '49',
#   'tb': '211',
#   'team_brief': 'Brewers',
#   'sport_id': '1',
#   'name_display_last_init': 'Aguilar, J',
#   'bb': '49',
#   'avg': '.280',
#   'slg': '.569',
#   'ops': '.933',
#   'hbp': '4',
#   'team_abbrev': 'MIL',
#   'so': '106',
#   'league_id': '104',
#   'sf': '7',
#   'team': 'mil',
#   'league': 'NL',
#   'cs': '0',
#   'sb': '0',
#   'go_ao': '0.90',
#   'last_name': 'Aguilar',
#   'player_id': '542583',
#   'ibb': '3',
#   'player_qualifier': '431',
#   'team_id': '158',
#   'go': '86',
#   'hr': '29',
#   'minimum_qualifier': '400',
#   'gdp': '14',
#   'name_display_roster': 'Aguilar, Jesus',
#   'qualifies': 'Y',
#   'rbi': '90',
#   'name_first': 'Jesus',
#   'bats': 'R',
#   'xbh': '49',
#   'g': '116',
#   'd': '20',
#   'team_name': 'Milwaukee Brewers',
#   'sport': 'MLB',
#   'tpa': '431',
#   'name_display_last_first': 'Aguilar, Jesus',
#   'h': '104',
#   'obp': '.364',
#   't': '0',
#   'ao': '96',
#   'r': '63',
#   'ab': '371',
#   'name_last': 'Aguilar'},
#  {'gidp': '17',
#   'sac': '0',
#   'np': '2160',
#   'name_display_first_last': 'Brian Anderson',
#   'pos': 'RF',
#   'rank': '50',
#   'tb': '196',
#   'team_brief': 'Marlins',
#   'sport_id': '1',
#   'name_display_last_init': 'Anderson, B',
#   'bb': '50',
#   'avg': '.278',
#   'slg': '.398',
#   'ops': '.754',
#   'hbp': '11',
#   'team_abbrev': 'MIA',
#   'so': '96',
#   'league_id': '104',
#   'sf': '1',
#   'team': 'mia',
#   'league': 'NL',
#   'cs': '4',
#   'sb': '2',
#   'go_ao': '1.50',
#   'last_name': 'Anderson',
#   'player_id': '605119',
#   'ibb': '2',
#   'player_qualifier': '555',
#   'team_id': '146',
#   'go': '167',
#   'hr': '9',
#   'minimum_qualifier': '397',
#   'gdp': '17',
#   'name_display_roster': 'Anderson, Brian',
#   'qualifies': 'Y',
#   'rbi': '54',
#   'name_first': 'Brian',
#   'bats': 'R',
#   'xbh': '38',
#   'g': '127',
#   'd': '26',
#   'team_name': 'Miami Marlins',
#   'sport': 'MLB',
#   'tpa': '555',
#   'name_display_last_first': 'Anderson, Brian',
#   'h': '137',
#   'obp': '.357',
#   't': '3',
#   'ao': '111',
#   'r': '68',
#   'ab': '493',
#   'name_last': 'Anderson'}]

# %%
import pandas as pd

# %%
df = pd.DataFrame(res.json()["stats_sortable_player"]["queryResults"]["row"])

# %%
df
# Out:
#      ab   ao   avg bats  bb  cs   d    g gdp gidp ... sport_id  t   tb team  \
# 0   424  136  .340    R  60   3  37  108   4    4 ...        1  5  272  bos
# 1   463   82  .333    R  53   1  34  121  15   15 ...        1  1  304  bos
# 2   415  111  .328    R  42   2  24  106  12   12 ...        1  2  191  hou
# 3   486  120  .319    L  63   3  35  126   7    7 ...        1  3  256  atl
# 4   483  124  .315    R  21  10  27  117  16   16 ...        1  2  210  sea
# 5   449   68  .314    L  42   3  27  113   9    9 ...        1  4  239  mil
# 6   492  148  .313    L  53   1  37  126  16   16 ...        1  2  237  atl
# 7   467  124  .310    L  33   2  26  123  12   12 ...        1  1  230  cin
# 8   372   98  .309    R  99   2  21  109   5    5 ...        1  3  232  ana
# 9   447  124  .309    R  59   2  26  119  12   12 ...        1  2  258  col
# 10  409   99  .308    R  39   3  22  119  13   13 ...        1  0  193  sln
# 11  417   83  .307    R  58   7  20  110   6    6 ...        1  1  177  mil
# 12  490  156  .306    R  60   1  27  127  15   15 ...        1  2  268  lan
# 13  443   87  .305    L  38   0  24  113  10   10 ...        1  5  241  ari
# 14  414  137  .304    L  17   3  26  109  10   10 ...        1  6  197  pit
# 15  369   85  .304    L  38   9  21  115   9    9 ...        1  9  157  tba
# 16  483  157  .302    R  49   8  33  123  10   10 ...        1  1  208  kca
# 17  455  133  .301    L  39   3  31  114  12   12 ...        1  2  214  cle
# 18  465  120  .299    L  61   2  35  120   6    6 ...        1  6  231  bos
# 19  432  138  .299    R  30   2  23  114  14   14 ...        1  3  182  ana
# 20  457  163  .298    S  84   5  32  124   2    2 ...        1  3  285  cle
# 21  411  103  .297    R  49   0  20  109  15   15 ...        1  2  230  cin
# 22  440  108  .295    R  19   0  36  115   7    7 ...        1  2  230  nya
# 23  471   99  .293    R  76   3  26  124   4    4 ...        1  4  256  ari
# 24  386  137  .293    R  38   1  30  100   3    3 ...        1  1  193  was
# 25  410   88  .293    R  31   5  17  106  12   12 ...        1  1  151  tba
# 26  493  175  .292    R  28   6  26  124  11   11 ...        1  4  202  cin
# 27  487  125  .292    R  35   1  35  122   6    6 ...        1  4  239  det
# 28  463   93  .292    R  18   5  33  123  10   10 ...        1  8  262  chn
# 29  474  132  .291    R  38   5  34  124   9    9 ...        1  5  260  col
# 30  365   88  .290    L  22   4  18  107  10   10 ...        1  5  155  tba
# 31  504  153  .290    L  30   2  30  124   4    4 ...        1  2  246  min
# 32  509  152  .289    S  60   8  40  124   5    5 ...        1  1  276  cle
# 33  491  117  .287    R  41   2  26  125  16   16 ...        1  1  199  mia
# 34  384  109  .286    R  27   2  26   98   7    7 ...        1  3  190  mia
# 35  490   93  .286    R  49   0  27  125  14   14 ...        1  1  265  nya
# 36  372   63  .285    R  68   3  20   99   8    8 ...        1  0  204  nya
# 37  358   73  .285    L  31   2  23  104   5    5 ...        1  3  173  col
# 38  408  112  .284    L  91   0  24  118  14   14 ...        1  2  171  cin
# 39  395  107  .284    R  43   2  22  104  12   12 ...        1  1  151  sfn
# 40  388  109  .284    R  34   0  20  120  10   10 ...        1  0  184  lan
# 41  464   82  .282    L  80   1  28  119   8    8 ...        1  1  224  tex
# 42  404  103  .282    R  43   2  37  106  12   12 ...        1  3  214  bos
# 43  422  140  .282    R  18   1  27  106  20   20 ...        1  1  172  hou
# 44  476  168  .282    R  72   4  38  124  13   13 ...        1  1  246  hou
# 45  469  135  .281    R  21   0  31  117  17   17 ...        1  0  202  bal
# 46  388  105  .281    R  25   0  17  114  12   12 ...        1  1  188  phi
# 47  442  139  .281    S  43   3  43  117  10   10 ...        1  3  227  ari
# 48  371   96  .280    R  49   0  20  116  14   14 ...        1  0  211  mil
# 49  493  111  .278    R  50   4  26  127  17   17 ...        1  3  196  mia
#
#    team_abbrev team_brief team_id              team_name  tpa xbh
# 0          BOS    Red Sox     111         Boston Red Sox  493  69
# 1          BOS    Red Sox     111         Boston Red Sox  524  73
# 2          HOU     Astros     117         Houston Astros  463  35
# 3          ATL     Braves     144         Atlanta Braves  559  58
# 4          SEA   Mariners     136       Seattle Mariners  516  38
# 5          MIL    Brewers     158      Milwaukee Brewers  498  52
# 6          ATL     Braves     144         Atlanta Braves  554  53
# 7          CIN       Reds     113        Cincinnati Reds  512  46
# 8          LAA     Angels     108     Los Angeles Angels  482  54
# 9          COL    Rockies     115       Colorado Rockies  512  58
# 10         STL  Cardinals     138    St. Louis Cardinals  453  37
# 11         MIL    Brewers     158      Milwaukee Brewers  482  30
# 12         LAD    Dodgers     119    Los Angeles Dodgers  555  58
# 13         ARI    D-backs     109   Arizona Diamondbacks  486  53
# 14         PIT    Pirates     134     Pittsburgh Pirates  439  43
# 15          TB       Rays     139         Tampa Bay Rays  421  32
# 16          KC     Royals     118     Kansas City Royals  544  43
# 17         CLE    Indians     114      Cleveland Indians  504  47
# 18         BOS    Red Sox     111         Boston Red Sox  534  56
# 19         LAA     Angels     108     Los Angeles Angels  472  34
# 20         CLE    Indians     114      Cleveland Indians  549  72
# 21         CIN       Reds     113        Cincinnati Reds  474  50
# 22         NYY    Yankees     147       New York Yankees  465  58
# 23         ARI    D-backs     109   Arizona Diamondbacks  553  58
# 24         WSH  Nationals     120   Washington Nationals  433  47
# 25          TB       Rays     139         Tampa Bay Rays  448  22
# 26         CIN       Reds     113        Cincinnati Reds  536  38
# 27         DET     Tigers     116         Detroit Tigers  527  57
# 28         CHC       Cubs     112           Chicago Cubs  491  67
# 29         COL    Rockies     115       Colorado Rockies  521  65
# 30          TB       Rays     139         Tampa Bay Rays  402  30
# 31         MIN      Twins     142        Minnesota Twins  537  54
# 32         CLE    Indians     114      Cleveland Indians  581  70
# 33         MIA    Marlins     146          Miami Marlins  538  37
# 34         MIA    Marlins     146          Miami Marlins  426  45
# 35         NYY    Yankees     147       New York Yankees  556  60
# 36         NYY    Yankees     147       New York Yankees  447  46
# 37         COL    Rockies     115       Colorado Rockies  392  40
# 38         CIN       Reds     113        Cincinnati Reds  509  35
# 39          SF     Giants     137   San Francisco Giants  443  28
# 40         LAD    Dodgers     119    Los Angeles Dodgers  430  38
# 41         TEX    Rangers     140          Texas Rangers  554  50
# 42         BOS    Red Sox     111         Boston Red Sox  457  59
# 43         HOU     Astros     117         Houston Astros  450  36
# 44         HOU     Astros     117         Houston Astros  560  63
# 45         BAL    Orioles     110      Baltimore Orioles  495  44
# 46         PHI   Phillies     143  Philadelphia Phillies  416  38
# 47         ARI    D-backs     109   Arizona Diamondbacks  494  64
# 48         MIL    Brewers     158      Milwaukee Brewers  431  49
# 49         MIA    Marlins     146          Miami Marlins  555  38
#
# [50 rows x 52 columns]
